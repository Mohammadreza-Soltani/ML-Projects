# %%
import numpy as np
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
#Ex 1
boston=datasets.load_boston()

# %%
x=boston.data
y=boston.target

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston=pd.DataFrame(boston.data,columns=boston.feature_names)

# %%
boston["price"]=y

# %%
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
#MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()
scale.fit(boston);

# %%
scale.data_min_
# Out:
# array([6.3200e-03, 0.0000e+00, 4.6000e-01, 0.0000e+00, 3.8500e-01,
#        3.5610e+00, 2.9000e+00, 1.1296e+00, 1.0000e+00, 1.8700e+02,
#        1.2600e+01, 3.2000e-01, 1.7300e+00, 5.0000e+00])

# %%
scale.data_max_
# Out:
# array([ 88.9762, 100.    ,  27.74  ,   1.    ,   0.871 ,   8.78  ,
#        100.    ,  12.1265,  24.    , 711.    ,  22.    , 396.9   ,
#         37.97  ,  50.    ])

# %%
scale.transform(boston)
# Out:
# array([[0.00000000e+00, 1.80000000e-01, 6.78152493e-02, ...,
#         1.00000000e+00, 8.96799117e-02, 4.22222222e-01],
#        [2.35922539e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         1.00000000e+00, 2.04470199e-01, 3.68888889e-01],
#        [2.35697744e-04, 0.00000000e+00, 2.42302053e-01, ...,
#         9.89737254e-01, 6.34657837e-02, 6.60000000e-01],
#        ...,
#        [6.11892474e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.07891832e-01, 4.20000000e-01],
#        [1.16072990e-03, 0.00000000e+00, 4.20454545e-01, ...,
#         9.91300620e-01, 1.31070640e-01, 3.77777778e-01],
#        [4.61841693e-04, 0.00000000e+00, 4.20454545e-01, ...,
#         1.00000000e+00, 1.69701987e-01, 1.53333333e-01]])

# %%
#normalize
from sklearn.preprocessing import normalize

# %%
n1=normalize(boston,norm="l1",axis=0)
n1
# Out:
# array([[3.45649292e-06, 3.13043478e-03, 4.09922612e-04, ...,
#         2.19917146e-03, 7.77827238e-04, 2.10496772e-03],
#        [1.49362059e-05, 0.00000000e+00, 1.25461163e-03, ...,
#         2.19917146e-03, 1.42757851e-03, 1.89447095e-03],
#        [1.49252677e-05, 0.00000000e+00, 1.25461163e-03, ...,
#         2.17662012e-03, 6.29446540e-04, 3.04343250e-03],
#        ...,
#        [3.32304604e-05, 0.00000000e+00, 2.11704621e-03, ...,
#         2.19917146e-03, 8.80912776e-04, 2.09619702e-03],
#        [5.99362435e-05, 0.00000000e+00, 2.11704621e-03, ...,
#         2.18005546e-03, 1.01211255e-03, 1.92955375e-03],
#        [2.59291660e-05, 0.00000000e+00, 2.11704621e-03, ...,
#         2.19917146e-03, 1.23077884e-03, 1.04371316e-03]])

# %%
n2=normalize(boston,norm="l2",axis=0)
n2
# Out:
# array([[3.01395767e-05, 3.08684289e-02, 7.85307229e-03, ...,
#         4.79270479e-02, 1.52411958e-02, 4.38451184e-02],
#        [1.30239215e-04, 0.00000000e+00, 2.40351606e-02, ...,
#         4.79270479e-02, 2.79727972e-02, 3.94606065e-02],
#        [1.30143837e-04, 0.00000000e+00, 2.40351606e-02, ...,
#         4.74355813e-02, 1.23337388e-02, 6.33927337e-02],
#        ...,
#        [2.89759602e-04, 0.00000000e+00, 4.05572088e-02, ...,
#         4.79270479e-02, 1.72611133e-02, 4.36624304e-02],
#        [5.22625983e-04, 0.00000000e+00, 4.05572088e-02, ...,
#         4.75104484e-02, 1.98319175e-02, 4.01913585e-02],
#        [2.26094515e-04, 0.00000000e+00, 4.05572088e-02, ...,
#         4.79270479e-02, 2.41165910e-02, 2.17398712e-02]])

# %%
#Ex 2
df=pd.read_csv(r"C:\Users\Zohreh HP17\Desktop\[FVDM9406] Machine_Learning_I\Files_and_codes\S03\code-3\Titanic.csv")
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
def f(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknown'

# %%
def g(tt):
    if tt in ['Mr']:
        return 1
    elif tt in ['Master']:
        return 3
    elif tt in ['Ms', 'Mlle', 'Miss']:
        return 4
    elif tt in ['Mrs','Mme']:
        return 5
    else:
        return 2

# %%
df['title'] = df['Name'].apply(f).apply(g)
df.head(5)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived  title
# 0         0      1
# 1         1      5
# 2         1      4
# 3         1      5
# 4         0      1

# %%
t=pd.crosstab(df["title"],df["Survived"])
t
# Out:
# Survived    0    1
# title
# 1         436   81
# 2          15    8
# 3          17   23
# 4          55  130
# 5          26  100

# %%
t_pct=t.div(t.sum(1).astype(float),axis=0)
t_pct
# Out:
# Survived         0         1
# title
# 1         0.843327  0.156673
# 2         0.652174  0.347826
# 3         0.425000  0.575000
# 4         0.297297  0.702703
# 5         0.206349  0.793651

# %%
t_pct.plot(kind='bar',stacked=True, title='Survival Rate by title')

plt.xlabel('title')

plt.ylabel('Survival Rate')
plt.show()

# %%
df=df.drop(["PassengerId","Name","Ticket"],axis=1)

# %%
df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived  title
# 0       3    male  22.0      1      0   7.2500   NaN        S         0      1
# 1       1  female  38.0      1      0  71.2833   C85        C         1      5
# 2       3  female  26.0      0      0   7.9250   NaN        S         1      4
# 3       1  female  35.0      1      0  53.1000  C123        S         1      5
# 4       3    male  35.0      0      0   8.0500   NaN        S         0      1

# %%
edt=pd.get_dummies(df["Embarked"])

# %%
edt
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
edt.drop(['S'], axis=1, inplace=True)

# %%
df=df.join(edt)

# %%
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived  \
# 0         3    male  22.0      1      0   7.2500   NaN        S         0
# 1         1  female  38.0      1      0  71.2833   C85        C         1
# 2         3  female  26.0      0      0   7.9250   NaN        S         1
# 3         1  female  35.0      1      0  53.1000  C123        S         1
# 4         3    male  35.0      0      0   8.0500   NaN        S         0
# ..      ...     ...   ...    ...    ...      ...   ...      ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN        S         0
# 887       1  female  19.0      0      0  30.0000   B42        S         1
# 888       3  female   NaN      1      2  23.4500   NaN        S         0
# 889       1    male  26.0      0      0  30.0000  C148        C         1
# 890       3    male  32.0      0      0   7.7500   NaN        Q         0
#
#      title  C  Q
# 0        1  0  0
# 1        5  1  0
# 2        4  0  0
# 3        5  0  0
# 4        1  0  0
# ..     ... .. ..
# 886      2  0  0
# 887      4  0  0
# 888      4  0  0
# 889      1  1  0
# 890      1  0  1
#
# [891 rows x 12 columns]

# %%
df.drop(["Embarked"],axis=1,inplace=True)

# %%
df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Survived  title  C  Q
# 0         3    male  22.0      1      0   7.2500   NaN         0      1  0  0
# 1         1  female  38.0      1      0  71.2833   C85         1      5  1  0
# 2         3  female  26.0      0      0   7.9250   NaN         1      4  0  0
# 3         1  female  35.0      1      0  53.1000  C123         1      5  0  0
# 4         3    male  35.0      0      0   8.0500   NaN         0      1  0  0
# ..      ...     ...   ...    ...    ...      ...   ...       ...    ... .. ..
# 886       2    male  27.0      0      0  13.0000   NaN         0      2  0  0
# 887       1  female  19.0      0      0  30.0000   B42         1      4  0  0
# 888       3  female   NaN      1      2  23.4500   NaN         0      4  0  0
# 889       1    male  26.0      0      0  30.0000  C148         1      1  1  0
# 890       3    male  32.0      0      0   7.7500   NaN         0      1  0  1
#
# [891 rows x 11 columns]

# %%
pd.crosstab(df["Sex"],df["Survived"])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
gp=df.groupby(by="Sex").mean()
gp
# Out:
#           Pclass        Age     SibSp     Parch       Fare  Survived  \
# Sex
# female  2.159236  27.915709  0.694268  0.649682  44.479818  0.742038
# male    2.389948  30.726645  0.429809  0.235702  25.523893  0.188908
#
#            title         C         Q
# Sex
# female  4.382166  0.232484  0.114650
# male    1.173310  0.164645  0.071057

# %%
df.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare    Survived  \
# count  891.000000  714.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208    0.383838
# std      0.836071   14.526497    1.102743    0.806057   49.693429    0.486592
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200    0.000000
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000
#
#             title           C           Q
# count  891.000000  891.000000  891.000000
# mean     2.304153    0.188552    0.086420
# std      1.624453    0.391372    0.281141
# min      1.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000
# 75%      4.000000    0.000000    0.000000
# max      5.000000    1.000000    1.000000
